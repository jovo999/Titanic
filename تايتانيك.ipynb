# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Titanic.csv')
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns.to_list()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
vr1 = df.Survived.value_counts()

# %%
plt.figure(figsize=(10,6))
plt.pie(vr1 , autopct='%1.1f%%')
plt.show()

# %%
 female = df[df.Sex == 'female']

# %%
 class_female = female.Pclass.value_counts()

# %%
plt.pie(class_female , labels=[3 , 1 ,2] , autopct='%1.1f%%')
plt.show()

# %%
df_female = df[(df.Age <30) & (df.Sex == 'female')]
vr5 = df_female.Survived.value_counts()

# %%
plt.pie(vr5 , autopct='%1.1f%%')
plt.show()

# %%
  df_male = df[(df.Age >40) & (df.Sex == 'male')]
  vr6 = df_male.Survived.value_counts()

# %%
plt.pie(vr6 , autopct='%1.1f%%')
plt.show()

# %%
plt.hist(df.Age , bins=20)
plt.show()

# %%
vr6 = df[df.Survived == 0].Age

counts , bins , _ = plt.hist(vr6 , bins = 20)
bin_centers = 0.5 * (bins[:-1] + bins[1:])
plt.plot(bin_centers , counts , marker = 'o')
plt.show()

# %%
survver = df[df.Survived == 1]

# %%
survver.Sex.value_counts()
# Out:
# Sex
# female    233
# male      109
# Name: count, dtype: int64

# %%
sns.countplot(x='Sex' , hue='Survived' , data=df)
plt.show()

# %%
temb = df.Pclass.value_counts()

# %%
list(temb)
# Out:
# 3
# 1
# 2

# %%
data = dict(temb)
x = data.keys()
y = data.values()

# %%
var = []

for i in x:
  if i ==1:
    var.append('First')
  elif i ==2:
    var.append('Second')
  else:
    var.append('Third')

# %%
plt.bar(var , y)
plt.show()

# %%
sns.countplot(x='Pclass' , hue='Survived' , data=df)
plt.show()
